# %% [markdown]
# # SVOMPTR-9B MoE: Colab Training Workflow
# This notebook trains the 9B MoE architecture on T4 GPUs.

# %%
# !pip install torch transformers accelerate datasets bitsandbytes
from svomptr_moe.train_chat_expert import train_chat_expert
from svomptr_moe.train_sub_experts import train_domain_experts

train_chat_expert() # Train 2.5B Core
train_domain_experts() # Train sub-experts
