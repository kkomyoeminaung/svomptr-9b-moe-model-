# %% [markdown]
# # SVOMPTR-9B MoE: Local CPU Inference
# Expert 0 (Chat) Always On | Sub-experts On-demand

# %%
from svomptr_moe.inference_chat_first import ChatFirstInference
inf = ChatFirstInference()
print(inf.chat('သုတေသနအကြောင်း ပြောပြပါ'))
